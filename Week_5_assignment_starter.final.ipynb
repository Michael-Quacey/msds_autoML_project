# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
# !conda create -n msds python=3.10.14 -y
# !conda activate msds
# !pip install --upgrade pycaret

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (3.3.2)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\FLORENCE MIKE\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: jinja2>=3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.1.5)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: sktime==0.26.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.14.4)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: pandas<2.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (8.6.1)
# Requirement already satisfied: xxhash in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: schemdraw==0.15 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: cloudpickle in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.13.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (7.0.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (8.32.0)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: numba>=0.55.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.61.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: packaging in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from sktime==0.26.0->pycaret) (24.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.3)
# Requirement already satisfied: zipp>=3.20 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.21.0)
# Requirement already satisfied: stack_data in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.1)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.50)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: decorator in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: colorama in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: matplotlib-inline in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: exceptiongroup in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (1.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.56.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (308)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.55.0->pycaret) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.2.0->pycaret) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.2.0->pycaret) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.15)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.6)
# Requirement already satisfied: retrying in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: setuptools in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (57.4.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.8)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: urllib3 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.3.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.12)
# Requirement already satisfied: wcwidth in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2025.1.31)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\florence mike\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.0)

# %%
import pandas as pd
df = pd.read_csv('churn_data_modified.csv')

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = pd.factorize(df[col])[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerID      7043 non-null   int64
#  1   tenure          7043 non-null   int64
#  2   PhoneService    7043 non-null   int64
#  3   Contract        7043 non-null   int64
#  4   PaymentMethod   7043 non-null   int64
#  5   MonthlyCharges  7043 non-null   float64
#  6   TotalCharges    7043 non-null   float64
#  7   Churn           7043 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 440.3 KB

# %% [markdown]
# # using pycaret to find an ML algorithm that performs best on the data

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_d9c13_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d9c13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9c13_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d9c13_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9c13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9c13_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d9c13_row0_col1" class="data row0 col1" >1768</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9c13_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d9c13_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9c13_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d9c13_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9c13_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d9c13_row3_col1" class="data row3 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9c13_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d9c13_row4_col1" class="data row4 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9c13_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d9c13_row5_col1" class="data row5 col1" >(4930, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9c13_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d9c13_row6_col1" class="data row6 col1" >(2113, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9c13_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d9c13_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9c13_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d9c13_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9c13_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d9c13_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d9c13_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d9c13_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d9c13_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d9c13_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d9c13_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d9c13_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d9c13_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d9c13_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d9c13_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d9c13_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d9c13_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d9c13_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d9c13_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d9c13_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d9c13_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d9c13_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d9c13_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d9c13_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d9c13_row18_col1" class="data row18 col1" >302f</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import setup, compare_models

# Set up for regression
automl = setup(df, target='Churn', session_id=5906)

# Compare regression models
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_576e8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_576e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_576e8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_576e8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_576e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_576e8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_576e8_row0_col1" class="data row0 col1" >5906</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_576e8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_576e8_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_576e8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_576e8_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_576e8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_576e8_row3_col1" class="data row3 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_576e8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_576e8_row4_col1" class="data row4 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_576e8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_576e8_row5_col1" class="data row5 col1" >(4930, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_576e8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_576e8_row6_col1" class="data row6 col1" >(2113, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_576e8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_576e8_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_576e8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_576e8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_576e8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_576e8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_576e8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_576e8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_576e8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_576e8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_576e8_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_576e8_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_576e8_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_576e8_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_576e8_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_576e8_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_576e8_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_576e8_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_576e8_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_576e8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_576e8_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_576e8_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_576e8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_576e8_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_576e8_row18_col1" class="data row18 col1" >8cfe</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_
row4_col1" class="data row4 col1" >0.7505</td>
#       <td id="T_f1419_row4_col2" class="data row4 col2" >0.8250</td>
#       <td id="T_f1419_row4_col3" class="data row4 col3" >0.7417</td>
#       <td id="T_f1419_row4_col4" class="data row4 col4" >0.5213</td>
#       <td id="T_f1419_row4_col5" class="data row4 col5" >0.6120</td>
#       <td id="T_f1419_row4_col6" class="data row4 col6" >0.4364</td>
#       <td id="T_f1419_row4_col7" class="data row4 col7" >0.4513</td>
#       <td id="T_f1419_row4_col8" class="data row4 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_f1419_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_f1419_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_f1419_row5_col1" class="data row5 col1" >0.7925</td>
#       <td id="T_f1419_row5_col2" class="data row5 col2" >0.8235</td>
#       <td id="T_f1419_row5_col3" class="data row5 col3" >0.4511</td>
#       <td id="T_f1419_row5_col4" class="data row5 col4" >0.6613</td>
#       <td id="T_f1419_row5_col5" class="data row5 col5" >0.5351</td>
#       <td id="T_f1419_row5_col6" class="data row5 col6" >0.4079</td>
#       <td id="T_f1419_row5_col7" class="data row5 col7" >0.4209</td>

# %%
best_model
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=5906, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 8)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_42846">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42846_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_42846_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_42846_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_42846_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_42846_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_42846_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_42846_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_42846_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42846_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42846_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_42846_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_42846_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_42846_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_42846_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_42846_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_42846_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_42846_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#       customerID  tenure  PhoneService  Contract  PaymentMethod  \
# 7041        7041       4             1         0              1
#
#       MonthlyCharges  TotalCharges  Churn  prediction_label  prediction_score
# 7041       74.400002    297.600006      1                 1            0.7569

# %% [markdown]
# # saving the model

# %%
save_model(best_model, 'LDA')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['customerID', 'tenure',
#                                               'PhoneService', 'Contract',
#                                               'PaymentMethod', 'MonthlyCharges',
#                                               'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categori...
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='log_loss',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              random_state=5906, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False))],
#           verbose=False),
#  'LDA.pkl')

# %% [markdown]
# # predicting

# %%
import pickle

with open('LDA_model.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('LDA_model.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(new_data)
# Out:
# array([1], dtype=int8)

# %%
loaded_lda = load_model('LDA')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_lda, new_data)
# Out:
#       customerID  tenure  PhoneService  Contract  PaymentMethod  \
# 7041        7041       4             1         0              1
#
#       MonthlyCharges  TotalCharges  prediction_label  prediction_score
# 7041       74.400002    297.600006                 1            0.7569

# %%
import pandas as pd
df_2 = pd.read_csv('new_churn_data.csv', index_col='customerID')
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 9305-CKSKC to 6348-TACGU
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tenure             5 non-null      int64
#  1   PhoneService       5 non-null      int64
#  2   Contract           5 non-null      int64
#  3   PaymentMethod      5 non-null      int64
#  4   MonthlyCharges     5 non-null      float64
#  5   TotalCharges       5 non-null      float64
#  6   charge_per_tenure  5 non-null      float64
# dtypes: float64(3), int64(4)
# memory usage: 320.0+ bytes

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# def load_data(filepath):
#     """
#     Loads churn data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv(filepath, index_col = "customerID")
#     return df
#
#
# def make_predictions(df):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     """
#     model = load_model('LDA')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'Churn_prediction'}, axis=1, inplace=True)
#     predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No Churn'},
#                                             inplace=True)
#     return predictions['Churn_prediction']
#
#
# if __name__ == "__main__":
#     df = load_data('new_churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %% [markdown]
# # Summary

# %% [markdown]
# # By using Pycaret, we
# 1. Loaded and prepared the churn data.
# 2. Compared ML algorithmns and selected the best performer based on AUC
# 3. Created a Python function to predict churn probability
# 4. Tested the function with new data

# %% [markdown]
# # Results
# The best performing model achieved an AUC of 0.84.
# The model demonstrated excellent performance on both training and testing data

# %% [markdown]
# # Recommendations:
# Monitor model performance on new data.
# Continuosusly collect and incorporate new data to improve model accuracy.
# Explore feature engineering and hyperparameter tuning for further improvements.
